# %% [markdown]
# <a href="https://colab.research.google.com/github/mgonzalez547-design/PROGCOM_B_2026/blob/main/votacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#suponer que la cantidad maxima de votantes son 10
#suponer que son 5 candidatos
v1=0
v2=0
v3=0
v4=0
v5=0
vn=0
vb=0
for votos in range(10):
  id=input("ingrese su CC:")
  voto=input("ingrese por quien quiere votar: \n1.elefante blanco\n2.pantera rosa\n3.jp\n4.paloma\n5.quevedito\n6.voto en blanco")
  if voto==1: v1+=1
  elif voto==2: v2+=1
  elif voto==3: v3+=1
  elif voto==4: v4+=1
  elif voto==5: v5+=1
  elif voto==6: vb+=1
  else: vn+=1
  print(f"resultados:\nelefante blanco:{v1}\npantera rosa:{v2}\njp:{v3}\npaloma:{v4}\nquevedito:{v5}\nvoto en blanco:{v6}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1005/2275991143.py in <cell line: 0>()
#       9 vb=0
#      10 for votos in range(10):
# ---> 11   id=input("ingrese su CC:")
#      12   voto=input("ingrese por quien quiere votar: \n1.elefante blanco\n2.pantera rosa\n3.jp\n4.paloma\n5.quevedito\n6.voto en blanco")
#      13   if voto==1: v1+=1
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
er que la cantidad maxima de votantes son 10
#suponer que son 5 candidatos
v1=0
v2=0
v3=0
v4=0
v5=0
vn=0
vb=0
while votico=="s" and persona<=10:
  id=input("ingrese su CC:")
  voto=input("ingrese por quien quiere votar: \n1.elefante blanco\n2.pantera rosa\n3.jp\n4.paloma\n5.quevedito\n6.voto en blanco")
  if voto=="1": v1+=1
  elif voto=="2": v2+=1
  elif voto=="3": v3+=1
  elif voto=="4": v4+=1
  elif voto=="5": v5+=1
  elif voto=="6": vb+=1
  else: vn+=1
  PermissionError

  print(f"resultados:\nelefante blanco:{v1}\npantera rosa:{v2}\njp:{v3}\npaloma:{v4}\nquevedito:{v5}\nvoto en blanco:{v6}")

# %% [markdown]
# #Listas
# 1. tienen index(numeracion)
# 2. son finitas
# 3. son mutables
#  sintaxis
#  ```
#  #Forma canonica
#  variable=[]
#  #Extension
#  variable=[e,e1,e2,e3,...,en]
#  #comprension:formula que genera todos los elementos de la list

# %%
figura=["angelitos","estrella fugaz","dinosaurios","diablitos"]
cantidad=[4,2,5,3]

# %% [markdown]
# operaciones con listas
# 1. recorrer listas
# 2. verificar elementos dentro de la lista
# 3.borrar elementos en la lista
# 4. agregar elmentos a la lista
# 5. mutabilidad de la lista

# %% [markdown]
# 1.Recorrer lista

# %%
figura=["angelitos","estrella fugaz","dinosaurios","diablitos"]
#len:calcula el tamaño de un dato
for elemento in range(len(figura)):
  print(figura[elemento])
# Out:
# angelitos
# estrella fugaz
# dinosaurios
# diablitos

# %%
figura=["angelitos","estrella fugaz","dinosaurios","diablitos"]
cantidad=[4,2,5,3]
for elemento in range (len(figura)):
  print(figura[elemento] ,":", cantidad[elemento])
# Out:
# angelitos : 4
# estrella fugaz : 2
# dinosaurios : 5
# diablitos : 3

# %% [markdown]
# ###2. verifificar elementos dentro de la lista

# %%
user=input("que figura quiere comprar?")
for elemento in range (len(figura)):
  if user==figura[elemento]: print("si hay galleta")
else: print("no hay galleta")
# Out:
# que figura quiere comprar?chocolate
# no hay galleta

# %%
if user in figura: print("si hay galleta")
else: print("no hay galleta")
# Out:
# no hay galleta
